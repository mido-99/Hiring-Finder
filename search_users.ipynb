# %%
https://github.com/langchain-ai ?q=&type=all&language=typescript&sort=stargazers
https://github.com/langchain-ai

# %%
def prepare_repos_page(url):
    
    query = "?q=&type=all&language=typescript&sort=stargazers"
    return url + query

# %%
df3.github = df3.github.apply(lambda x: prepare_repos_page(x))
# Out:
# C:\Users\Mido Hany\AppData\Local\Temp\ipykernel_19956\2562030609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.github = df3.github.apply(lambda x: prepare_repos_page(x))

# %%
df3.github[79]
# Out:
# 'https://github.com/supertokens?q=&type=all&language=typescript&sort=stargazers'

# %%
df3['github'] = df3['github'].apply(lambda x: prepare_repos_page(x))
df3.loc[0, 'github']
# Out:
# C:\Users\Mido Hany\AppData\Local\Temp\ipykernel_19956\3265245889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['github'] = df3['github'].apply(lambda x: prepare_repos_page(x))
# 'https://github.com/bluesky-social?q=&type=all&language=typescript&sort=stargazers?q=&type=all&language=typescript&sort=stargazers'

# %%
df3
# Out:
#               name                                             github  \
# 0   bluesky-social  https://github.com/bluesky-social?q=&type=all&...
# 1     langchain-ai  https://github.com/langchain-ai?q=&type=all&la...
# 2         TanStack  https://github.com/TanStack?q=&type=all&langua...
# 3             unjs  https://github.com/unjs?q=&type=all&language=t...
# 4         denoland  https://github.com/denoland?q=&type=all&langua...
# ..             ...                                                ...
# 95          linear  https://github.com/linear?q=&type=all&language...
# 96  AssemblyScript  https://github.com/AssemblyScript?q=&type=all&...
# 97        syncswap  https://github.com/syncswap?q=&type=all&langua...
# 98      nextui-org  https://github.com/nextui-org?q=&type=all&lang...
# 99       lifinance  https://github.com/lifinance?q=&type=all&langu...
#
#                                             api
# 0   https://api.github.com/users/bluesky-social
# ...

# %%
import requests
import os
from time import sleep
import pandas as pd

# %%
def search_organizations_by_criteria(token=None, min_followers=100, max_followers=5000, languages=None, per_page=100, start_page=1, max_pages=1):
    headers = {"Accept": "application/vnd.github.v3+json"}
    if token:
        headers["Authorization"] = f"token {token}"
    
    organizations = []
    base_url = "https://api.github.com/search/users"
    
    for language in languages:
        query = f"type:org followers:{min_followers}..{max_followers} language:{language}"
        
        for page in range(start_page, start_page+max_pages):
            params = {
                'q': query,
                'per_page': per_page,
                'page': page
            }
            sleep(1)
            
            response = requests.get(base_url, headers=headers, params=params)
            
            if response.status_code == 200:
                data = response.json()
                organizations.extend(data.get('items', []))
                print(f"Found total of {data['total_count']} organizations in {language} search")
                
                # Stop if fewer results than the per_page value were returned
                if len(data.get('items', [])) < per_page:
                    break
            else:
                print(f"Error: {response.status_code} - {response.json()}")
                response.raise_for_status()
    
    return organizations

# %%
organizations[0]
# Out:
# {'login': 'bluesky-social',
#  'id': 94650532,
#  'node_id': 'O_kgDOBaRApA',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/94650532?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/bluesky-social',
#  'html_url': 'https://github.com/bluesky-social',
#  'followers_url': 'https://api.github.com/users/bluesky-social/followers',
#  'following_url': 'https://api.github.com/users/bluesky-social/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/bluesky-social/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/bluesky-social/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/bluesky-social/subscriptions',
#  'organizations_url': 'https://api.github.com/users/bluesky-social/orgs',
#  'repos_url': 'https://api.github.com/users/bluesky-social/repos',
#  'events_url': 'https://api.github.com/users/bluesky-social/events{/privacy}',
# ...

# %%
# Define criteria
languages = ['typescript']
min_followers = 100
max_followers = 5000
per_page = 100
start_page = 1
max_pages = 1

# Search for organizations
organizations = search_organizations_by_criteria(token=None, min_followers=min_followers, max_followers=max_followers, languages=languages, per_page=per_page, max_pages=max_pages)

# Print the results
for org in organizations:
    print(f"Organization: {org['login']}, Followers: {org['followers_url']}")

print(f"Total organizations found: {len(organizations)}")
# Out:
# Found total of 502 organizations in typescript search
# Organization: bluesky-social, Followers: https://api.github.com/users/bluesky-social/followers
# Organization: langchain-ai, Followers: https://api.github.com/users/langchain-ai/followers
# Organization: TanStack, Followers: https://api.github.com/users/TanStack/followers
# Organization: unjs, Followers: https://api.github.com/users/unjs/followers
# Organization: denoland, Followers: https://api.github.com/users/denoland/followers
# Organization: berachain, Followers: https://api.github.com/users/berachain/followers
# Organization: prisma, Followers: https://api.github.com/users/prisma/followers
# Organization: radix-ui, Followers: https://api.github.com/users/radix-ui/followers
# Organization: nestjs, Followers: https://api.github.com/users/nestjs/followers
# Organization: total-typescript, Followers: https://api.github.com/users/total-typescript/followers
# ...

# %%
organizations[50]
# Out:
# {'login': 'a16z-infra',
#  'id': 130202746,
#  'node_id': 'O_kgDOB8K8eg',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/130202746?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/a16z-infra',
#  'html_url': 'https://github.com/a16z-infra',
#  'followers_url': 'https://api.github.com/users/a16z-infra/followers',
#  'following_url': 'https://api.github.com/users/a16z-infra/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/a16z-infra/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/a16z-infra/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/a16z-infra/subscriptions',
#  'organizations_url': 'https://api.github.com/users/a16z-infra/orgs',
#  'repos_url': 'https://api.github.com/users/a16z-infra/repos',
#  'events_url': 'https://api.github.com/users/a16z-infra/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/a16z-infra/received_events',
#  'type': 'Organization',
# ...

# %%
def get_webstie(api):
    headers = {"Accept": "application/vnd.github.v3+json"}
    
    resp = requests.get(api, headers=headers).json()
    site = resp['blog']
    return site

# %%
df2 = pd.DataFrame(organizations)

df3 = df2[['login', 'html_url']]

df3.rename(columns={'login': 'name', 'html_url': 'github'}, inplace=True)
df3.head()

df3['api'] = df2['url']
df3

df3['website'] = df3['api'].apply(lambda x: get_webstie(x))
# Out:
# C:\Users\Mido Hany\AppData\Local\Temp\ipykernel_19956\543984332.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.rename(columns={'login': 'name', 'html_url': 'github'}, inplace=True)
# C:\Users\Mido Hany\AppData\Local\Temp\ipykernel_19956\543984332.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['api'] = df2['url']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [136], line 11
#       8 df3['api'] = df2['url']
# ...

# %%
df3

# %%
headers = {"Accept": "application/vnd.github.v3+json"}
GITHUB_TOKEN = ''
headers["Authorization"] = f"token {GITHUB_TOKEN}"

df = pd.DataFrame(columns=['Organization', 'Github', 'Website'])

githubs = []
for org in organizations[:2]:
    
    
    repos_url = org['repos_url']
    repos = requests.get(repos_url, headers=headers).json()
    sorted_repos = sorted(repos, key=lambda x: x['stargazers_count'], reverse=True)
    repos_urls = [repo['html_url'] for repo in sorted_repos]
    repos_all.append(repos_urls)

df['Organization'] = [org['login'] for org in organizations[:2]]
df['Repos'] = repos_all
df['Github'] = [org['login'] for org in organizations[:2]]
print(df)
#     df.to_csv('Organizations_v2.csv', index=False)
# Out:
#      Organization          Github  \
# 0  bluesky-social  bluesky-social
# 1    langchain-ai    langchain-ai
#
#                                                Repos
# 0  [https://github.com/bluesky-social/social-app,...
# 1  [https://github.com/langchain-ai/langchain, ht...

# %%
repos_urls[0]
# Out:
# 'https://github.com/langchain-ai/langchain'

# %%
headers = {"Accept": "application/vnd.github.v3+json"}
token = ''
if token:
    headers["Authorization"] = f"token {token}"

df = pd.DataFrame()

githubs = []
repos_all = []
for org in organizations[:2]:
    # Repos urls
    repos_url = org['repos_url']
    repos = requests.get(repos_url, headers=headers).json()
    sorted_repos = sorted(repos, key=lambda x: x['stargazers_count'], reverse=True)
    repos_urls = [repo['html_url'] for repo in sorted_repos]
    repos_all.append(repos_urls)

    # Website
    github_url = org['url']
    github = requests.get(github_url, headers=headers).json()
    website = github['blog']
    githubs.append(website)

df['Organization'] = [org['login'] for org in organizations[:2]]
df['Repos'] = repos_all
df['Website'] = githubs

# %%
df.iloc[1, 1]
# Out:
# ['https://github.com/langchain-ai/langchain',
#  'https://github.com/langchain-ai/chat-langchain',
#  'https://github.com/langchain-ai/langchain-nextjs-template',
#  'https://github.com/langchain-ai/langchain-extract',
#  'https://github.com/langchain-ai/auto-evaluator',
#  'https://github.com/langchain-ai/langchain-aiplugin',
#  'https://github.com/langchain-ai/langchain-teacher',
#  'https://github.com/langchain-ai/langchain-benchmarks',
#  'https://github.com/langchain-ai/chat-langchainjs',
#  'https://github.com/langchain-ai/langchain-aws-template',
#  'https://github.com/langchain-ai/kork',
#  'https://github.com/langchain-ai/langchain-template-poe-fastapi',
#  'https://github.com/langchain-ai/langchain-google',
#  'https://github.com/langchain-ai/langchain-cloudflare-nuxt-template',
#  'https://github.com/langchain-ai/langchain-postgres',
#  'https://github.com/langchain-ai/langchain-aws',
#  'https://github.com/langchain-ai/helm',
# ...

# %%
process_data(organizations[:2])
# Out:
#      Organization          Github  \
# 0  bluesky-social  bluesky-social
# 1    langchain-ai    langchain-ai
#
#                                                Repos
# 0  [{'id': 439447708, 'node_id': 'R_kgDOGjFwnA', ...
# 1  [{'id': 756489494, 'node_id': 'R_kgDOLRcdFg', ...

# %%
organizations
# Out:
# [{'login': 'bluesky-social',
#   'id': 94650532,
#   'node_id': 'O_kgDOBaRApA',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/94650532?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/bluesky-social',
#   'html_url': 'https://github.com/bluesky-social',
#   'followers_url': 'https://api.github.com/users/bluesky-social/followers',
#   'following_url': 'https://api.github.com/users/bluesky-social/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/bluesky-social/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/bluesky-social/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/bluesky-social/subscriptions',
#   'organizations_url': 'https://api.github.com/users/bluesky-social/orgs',
#   'repos_url': 'https://api.github.com/users/bluesky-social/repos',
#   'events_url': 'https://api.github.com/users/bluesky-social/events{/privacy}',
# ...

# %%
for org in organizations[:2]:
    print(org)
# Out:
# {'login': 'actions', 'id': 44036562, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MDM2NTYy', 'avatar_url': 'https://avatars.githubusercontent.com/u/44036562?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/actions', 'html_url': 'https://github.com/actions', 'followers_url': 'https://api.github.com/users/actions/followers', 'following_url': 'https://api.github.com/users/actions/following{/other_user}', 'gists_url': 'https://api.github.com/users/actions/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/actions/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/actions/subscriptions', 'organizations_url': 'https://api.github.com/users/actions/orgs', 'repos_url': 'https://api.github.com/users/actions/repos', 'events_url': 'https://api.github.com/users/actions/events{/privacy}', 'received_events_url': 'https://api.github.com/users/actions/received_events', 'type': 'Organization', 'site_admin': False, 'score': 1.0}
# ...

# %%
def get_org_repos(org, token=None, per_page=100, start_page=1, max_pages=1):
                  
    headers = {"Accept": "application/vnd.github.v3+json"}
    if token:
        headers["Authorization"] = f"token {token}"
    
    repos = []
    
    url = f"https://api.github.com/orgs/{org}/repos"
    for page in range(start_page, start_page+max_pages):
        params = {
            'per_page': per_page,
            'page': start_page
            }
        response = requests.get(base_url, headers=headers, params=params)
        if response.status_code == 200:
            repos = response.json()
